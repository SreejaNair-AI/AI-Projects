# %%
pip install azure-cognitiveservices-vision-computervision
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
  pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
  import os
  import matplotlib.pyplot as plt
  from azure.cognitiveservices.vision.computervision import ComputerVisionClient
  from msrest.authentication import CognitiveServicesCredentials
  from PIL import Image

# %%
key = "5s6QKWOYEsUOjdpxUp330FEqZX1DtfZo966cyWFvnUHK5sXQlnOkJQQJ99ALAC4f1cMXJ3w3AAAAACOGYfWP"
endpoint = "https://sreejaaihub5099610328.cognitiveservices.azure.com/"

computervision_client = ComputerVisionClient(endpoint, CognitiveServicesCredentials(key))

# %%
  image_path = "assets/testimage.jpg"
  image_stream = open(image_path, "rb")

# %%
description_results = computervision_client.describe_image_in_stream(image_stream)

# %%
for caption in description_results.captions:
      print(f"'{caption.text}' with confidence {caption.confidence * 100:.2f}%")
# Out:
# 'a person sitting under a tree reading a book' with confidence 58.18%

# %%
image = Image.open(image_path)
plt.imshow(image)
plt.axis("off")
plt.show()

# %%
  image_path = "assets/test.jpg"
  image_stream = open(image_path, "rb")

# %%
description_results = computervision_client.describe_image_in_stream(image_stream)

# %%
for caption in description_results.captions:
      print(f"'{caption.text}' with confidence {caption.confidence * 100:.2f}%")
# Out:
# 'a man holding a stop sign' with confidence 61.95%

# %%
image_path = "assets/test1.jpg"
image_stream = open(image_path, "rb")

# %%
description_results = computervision_client.describe_image_in_stream(image_stream)

# %%
for caption in description_results.captions:
      print(f"'{caption.text}' with confidence {caption.confidence * 100:.2f}%")
# Out:
# 'a man smiling for the camera' with confidence 51.34%

# %%
import os
import matplotlib.pyplot as plt
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from azure.cognitiveservices.vision.computervision.models import VisualFeatureTypes
from msrest.authentication import CognitiveServicesCredentials

# %%
key = "5s6QKWOYEsUOjdpxUp330FEqZX1DtfZo966cyWFvnUHK5sXQlnOkJQQJ99ALAC4f1cMXJ3w3AAAAACOGYfWP"
endpoint = "https://sreejaaihub5099610328.cognitiveservices.azure.com/"
computervision_client = ComputerVisionClient(endpoint, CognitiveServicesCredentials(key))

# %%
  image_path = "assets/textocr.jpg"
  image_stream = open(image_path, "rb")

# %%
description_result = computervision_client.describe_image_in_stream(image_stream)

# %%
  for caption in description_result.captions:
      print(f"Description: {caption.text}, Confidence: {caption.confidence * 100:.2f}%")
# Out:
# Description: text, Confidence: 94.58%

# %%
  plt.imshow(plt.imread(image_path))
  plt.axis("off")
  plt.show()

# %%
image_path = "assets/test2.jpg"
image_stream = open(image_path, "rb")

# %%
description_results = computervision_client.describe_image_in_stream(image_stream)

# %%
  for caption in description_result.captions:
      print(f"Description: {caption.text}, Confidence: {caption.confidence * 100:.2f}%")
# Out:
# Description: text, Confidence: 94.58%
